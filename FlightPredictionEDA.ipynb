# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaMohanty374/EDAs/blob/main/FlightPredictionEDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df = pd.read_excel('Data_Train.xlsx')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
test_df = pd.read_excel('Test_set.xlsx')

# %%
test_df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
test_df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info'],
#       dtype='object')

# %%
final_df = train_df.append(test_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-714863615.py in <cell line: 0>()
# ----> 1 final_df = train_df.append(test_df)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
train_df['Day'] = train_df['Date_of_Journey'].str.split('/').str[0]
train_df['Month'] = train_df['Date_of_Journey'].str.split('/').str[1]
train_df['Year'] = train_df['Date_of_Journey'].str.split('/').str[2]

# %%
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897  24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662   1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882   9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218  12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302  01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
train_df['Day'] = train_df['Date_of_Journey'].apply(lambda x:x.split('/')).str[0]
train_df['Month'] = train_df['Date_of_Journey'].apply(lambda x:x.split('/')).str[1]
train_df['Year'] = train_df['Date_of_Journey'].apply(lambda x:x.split('/')).str[2]

# %%
train_df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Day  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897  24
# 1    05:50         13:15   7h 25m     2 stops         No info   7662   1
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882   9
# 3    18:05         23:30   5h 25m      1 stop         No info   6218  12
# 4    16:50         21:35   4h 45m      1 stop         No info  13302  01
#
#   Month  Year
# 0    03  2019
# 1    05  2019
# 2    06  2019
# ...

# %%
train_df['Day'] = train_df['Day'].astype(int)
train_df['Month'] = train_df['Month'].astype(int)
train_df['Year'] = train_df['Year'].astype(int)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
#  11  Day              10683 non-null  int64
#  12  Month            10683 non-null  int64
#  13  Year             10683 non-null  int64
# dtypes: int64(4), object(10)
# memory usage: 1.1+ MB

# %%
train_df.drop(columns = 'Date_of_Journey', axis=1, inplace=True)

# %%
train_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Day  Month  Year  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897   24      3  2019
# 1         13:15   7h 25m     2 stops         No info   7662    1      5  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882    9      6  2019
# 3         23:30   5h 25m      1 stop         No info   6218   12      5  2019
# 4         21:35   4h 45m      1 stop         No info  13302    1      3  2019
#
#   Departure Arrival
# 0     22:20   01:10
# 1     05:50   13:15
# ...

# %%
train_df['Departure'] = (train_df['Dep_Time'].str.split(' ').str[0])
train_df['Arrival'] = train_df['Arrival_Time'].str.split(' ').str[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Dep_Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2358446663.py in <cell line: 0>()
# ...

# %%
train_df.drop(columns = ['Hours', 'Minutes'], axis =1, inplace=True)

# %%
train_df['Departure'] = train_df['Departure'].str.replace(":", "", regex=False)
train_df['Arrival'] = train_df['Arrival'].str.replace(":", "", regex=False)

# %%
train_df.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#    Arrival_Time Duration Total_Stops Additional_Info  Price  Day  Month  Year  \
# 0  01:10 22 Mar   2h 50m    non-stop         No info   3897   24      3  2019
# 1         13:15   7h 25m     2 stops         No info   7662    1      5  2019
# 2  04:25 10 Jun      19h     2 stops         No info  13882    9      6  2019
# 3         23:30   5h 25m      1 stop         No info   6218   12      5  2019
# 4         21:35   4h 45m      1 stop         No info  13302    1      3  2019
#
#   Departure Arrival
# 0      2220    0110
# 1      0550    1315
# ...

# %%
train_df['Departure'] = train_df['Departure'].astype(int)
train_df['Arrival'] = train_df['Arrival'].astype(int)

# %%
train_df.drop(columns = ['Dep_Time', 'Arrival_Time'],axis=1, inplace=True)

# %%
train_df.head(4)
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
#
#   Total_Stops Additional_Info  Price  Day  Month  Year  Departure  Arrival
# 0    non-stop         No info   3897   24      3  2019       2220      110
# 1     2 stops         No info   7662    1      5  2019        550     1315
# 2     2 stops         No info  13882    9      6  2019        925      425
# 3      1 stop         No info   6218   12      5  2019       1805     2330

# %%
train_df.isnull().sum()
# Out:
# Airline            0
# Source             0
# Destination        0
# Route              1
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# Day                0
# Month              0
# Year               0
# Departure          0
# Arrival            0
# dtype: int64

# %%
train_df['Total_Stops'].unique()
# Out:
# array([ 0., nan,  1.])

# %%
train_df['Total_Stops'] = train_df['Total_Stops'].map({
    'non-stop':0,
    '1 stop':1,
    '2 stops':2,
    '3 stops':3,
    '4 stops':4,
})

# %%
train_df['Total_Stops'].isnull().sum()
# Out:
# np.int64(10683)

# %%
train_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#    Total_Stops Additional_Info  Price  Day  Month  Year  Departure  Arrival
# 0          NaN         No info   3897   24      3  2019       2220      110
# 1          NaN         No info   7662    1      5  2019        550     1315
# 2          NaN         No info  13882    9      6  2019        925      425
# 3          NaN         No info   6218   12      5  2019       1805     2330
# 4          NaN         No info  13302    1      3  2019       1650     2135

# %%
train_df.drop(columns = 'Total_Stops', axis = 1, inplace = True)

# %%
temp = pd.read_excel('Data_Train.xlsx')

# %%
train_df['Stops'] = temp['Total_Stops']

# %%
train_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info  Price  Day  Month  Year  Departure  Arrival     Stops
# 0         No info   3897   24      3  2019       2220      110  non-stop
# 1         No info   7662    1      5  2019        550     1315   2 stops
# 2         No info  13882    9      6  2019        925      425   2 stops
# 3         No info   6218   12      5  2019       1805     2330    1 stop
# 4         No info  13302    1      3  2019       1650     2135    1 stop

# %%
train_df['Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
train_df['Stops']=train_df['Stops'].map({
    'non-stop': 0,
    '1 stop':1,
    '2 stops':2,
    '3 stops':3,
    '4 stops':4,
})

# %%
train_df.head()
# Out:
#        Airline    Source Destination                  Route Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Additional_Info  Price  Day  Month  Year  Departure  Arrival  Stops
# 0         No info   3897   24      3  2019       2220      110    0.0
# 1         No info   7662    1      5  2019        550     1315    2.0
# 2         No info  13882    9      6  2019        925      425    2.0
# 3         No info   6218   12      5  2019       1805     2330    1.0
# 4         No info  13302    1      3  2019       1650     2135    1.0

# %%
train_df[train_df['Stops'].isnull()]
# Out:
#         Airline Source Destination Route Duration Additional_Info  Price  Day  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m         No info   7480    6
#
#       Month  Year  Departure  Arrival  Stops
# 9039      5  2019        945      925    NaN

# %%
train_df.drop(columns = 'Route', axis = 1, inplace = True)

# %%
train_df.head()
# Out:
#        Airline    Source Destination Duration Additional_Info  Price  Day  \
# 0       IndiGo  Banglore   New Delhi   2h 50m         No info   3897   24
# 1    Air India   Kolkata    Banglore   7h 25m         No info   7662    1
# 2  Jet Airways     Delhi      Cochin      19h         No info  13882    9
# 3       IndiGo   Kolkata    Banglore   5h 25m         No info   6218   12
# 4       IndiGo  Banglore   New Delhi   4h 45m         No info  13302    1
#
#    Month  Year  Departure  Arrival  Stops
# 0      3  2019       2220      110    0.0
# 1      5  2019        550     1315    2.0
# 2      6  2019        925      425    2.0
# 3      5  2019       1805     2330    1.0
# 4      3  2019       1650     2135    1.0

# %%
train_df['Duration_h'] = train_df['Duration'].str.split(" ").str[0]
train_df['Duration_m'] = temp['Duration'].str.split(" ").str[1]
train_df['Duration_h'] = train_df['Duration_h'].str.split("h").str[0]

# %%
train_df.head()
# Out:
#        Airline    Source Destination Duration Additional_Info  Price  Day  \
# 0       IndiGo  Banglore   New Delhi   2h 50m         No info   3897   24
# 1    Air India   Kolkata    Banglore   7h 25m         No info   7662    1
# 2  Jet Airways     Delhi      Cochin      19h         No info  13882    9
# 3       IndiGo   Kolkata    Banglore   5h 25m         No info   6218   12
# 4       IndiGo  Banglore   New Delhi   4h 45m         No info  13302    1
#
#    Month  Year  Departure  Arrival  Stops Duration_h Duration_m
# 0      3  2019       2220      110    0.0          2        50m
# 1      5  2019        550     1315    2.0          7        25m
# 2      6  2019        925      425    2.0         19        NaN
# 3      5  2019       1805     2330    1.0          5        25m
# 4      3  2019       1650     2135    1.0          4        45m

# %%
train_df['Duration_m'] = train_df['Duration_m'].str.split("m").str[0]

# %%
train_df.head()
# Out:
#        Airline    Source Destination Duration Additional_Info  Price  Day  \
# 0       IndiGo  Banglore   New Delhi   2h 50m         No info   3897   24
# 1    Air India   Kolkata    Banglore   7h 25m         No info   7662    1
# 2  Jet Airways     Delhi      Cochin      19h         No info  13882    9
# 3       IndiGo   Kolkata    Banglore   5h 25m         No info   6218   12
# 4       IndiGo  Banglore   New Delhi   4h 45m         No info  13302    1
#
#    Month  Year  Departure  Arrival  Stops Duration_h Duration_m
# 0      3  2019       2220      110    0.0          2         50
# 1      5  2019        550     1315    2.0          7         25
# 2      6  2019        925      425    2.0         19        NaN
# 3      5  2019       1805     2330    1.0          5         25
# 4      3  2019       1650     2135    1.0          4         45

# %%
train_df["Duration_h"].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '5m', '41', '40'], dtype=object)

# %%
train_df[(train_df['Source']=='Mumbai')&(train_df['Destination']=='Hyderabad')]
# Out:
#            Airline  Source Destination Duration              Additional_Info  \
# 59         Vistara  Mumbai   Hyderabad   25h 5m                      No info
# 67       Air India  Mumbai   Hyderabad   1h 30m                      No info
# 70     Jet Airways  Mumbai   Hyderabad   1h 25m                      No info
# 77          IndiGo  Mumbai   Hyderabad   1h 30m                      No info
# 98     Jet Airways  Mumbai   Hyderabad   1h 25m                      No info
# ...            ...     ...         ...      ...                          ...
# 10611  Jet Airways  Mumbai   Hyderabad   1h 25m  In-flight meal not included
# 10617       IndiGo  Mumbai   Hyderabad   1h 30m                      No info
# 10655  Jet Airways  Mumbai   Hyderabad   1h 25m                      No info
# 10671    Air India  Mumbai   Hyderabad   1h 20m                      No info
# 10675    Air India  Mumbai   Hyderabad   1h 20m                      No info
#
# ...

# %%
train_df['Duration_h'] = train_df['Duration_h'].str.split("m").str[0]

# %%
train_df['Duration_h'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '41', '40'], dtype=object)

# %%
train_df.head()
# Out:
#        Airline    Source Destination Duration Additional_Info  Price  Day  \
# 0       IndiGo  Banglore   New Delhi   2h 50m         No info   3897   24
# 1    Air India   Kolkata    Banglore   7h 25m         No info   7662    1
# 2  Jet Airways     Delhi      Cochin      19h         No info  13882    9
# 3       IndiGo   Kolkata    Banglore   5h 25m         No info   6218   12
# 4       IndiGo  Banglore   New Delhi   4h 45m         No info  13302    1
#
#    Month  Year  Departure  Arrival  Stops Duration_h Duration_m
# 0      3  2019       2220      110    0.0          2         50
# 1      5  2019        550     1315    2.0          7         25
# 2      6  2019        925      425    2.0         19        NaN
# 3      5  2019       1805     2330    1.0          5         25
# 4      3  2019       1650     2135    1.0          4         45

# %%
train_df['Duration_h'].astype(int)
train_df['Duration_m'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1025421863.py in <cell line: 0>()
#       1 train_df['Duration_h'].astype(int)
# ----> 2 train_df['Duration_m'].astype(int)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
train_df['Duration_m']=train_df['Duration_m'].fillna('0')

# %%
train_df['Duration_h'] = train_df['Duration_h'].astype(int)
train_df['Duration_m']= train_df['Duration_m'].astype(int)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Source           10683 non-null  object
#  2   Destination      10683 non-null  object
#  3   Duration         10683 non-null  object
#  4   Additional_Info  10683 non-null  object
#  5   Price            10683 non-null  int64
#  6   Day              10683 non-null  int64
#  7   Month            10683 non-null  int64
#  8   Year             10683 non-null  int64
#  9   Departure        10683 non-null  int64
#  10  Arrival          10683 non-null  int64
#  11  Stops            10682 non-null  float64
#  12  Duration_h       10683 non-null  int64
#  13  Duration_m       10683 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 1.1+ MB

# %%
train_df['Duration_h']=train_df['Duration_h'].apply(lambda x:x*60)

# %%
train_df.drop(columns = 'Duration', axis=1, inplace=True)

# %%
train_df['Duration_mins'] = train_df['Duration']

# %%
train_df.drop(columns = ['Duration_h', 'Duration_m', 'Duration'], axis=1,inplace=True)

# %%
train_df.head()
# Out:
#        Airline    Source Destination Additional_Info  Price  Day  Month  Year  \
# 0       IndiGo  Banglore   New Delhi         No info   3897   24      3  2019
# 1    Air India   Kolkata    Banglore         No info   7662    1      5  2019
# 2  Jet Airways     Delhi      Cochin         No info  13882    9      6  2019
# 3       IndiGo   Kolkata    Banglore         No info   6218   12      5  2019
# 4       IndiGo  Banglore   New Delhi         No info  13302    1      3  2019
#
#    Departure  Arrival  Stops  Duration_mins
# 0       2220      110    0.0            170
# 1        550     1315    2.0            445
# 2        925      425    2.0           1140
# 3       1805     2330    1.0            325
# 4       1650     2135    1.0            285

# %%
train_df.drop(6474, axis=0,inplace=True)
train_df.drop(2660, axis=0,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

labelE = LabelEncoder()
train_df['Airline'] = labelE.fit_transform(train_df['Airline'])
train_df['Source'] = labelE.fit_transform(train_df['Source'])
train_df['Destination'] = labelE.fit_transform(train_df['Destination'])
train_df['Additional_Info'] = labelE.fit_transform(train_df['Additional_Info'])

# %%
train_df.head()
# Out:
#    Airline  Source  Destination  Additional_Info  Price  Day  Month  Year  \
# 0        3       0            5                8   3897   24      3  2019
# 1        1       3            0                8   7662    1      5  2019
# 2        4       2            1                8  13882    9      6  2019
# 3        3       3            0                8   6218   12      5  2019
# 4        3       0            5                8  13302    1      3  2019
#
#    Departure  Arrival  Stops  Duration_mins
# 0       2220      110    0.0            170
# 1        550     1315    2.0            445
# 2        925      425    2.0           1140
# 3       1805     2330    1.0            325
# 4       1650     2135    1.0            285

# %%
train_df.to_csv("Feature_Engineered_train_data.csv", index=False)
